# %%
import pandas as pd
import pandas_profiling

# %%
# Read data from file
# Control delimiters, rows, column names with read_csv (see later) 
#data = pd.read_csv("S:/AFGITS/TestingServices/Data_Platform/Temp/FDW_BR.csv") 
data = pd.read_csv("C:/davabase/OpenWorkProjects/20190523_CANOS/01_Inbox/test.csv") 

# Preview the first 5 lines of the loaded data 
data.head()
# Out:
#    SUBMISSION_ID  ONSET_IND  TRANSACTION_ACCOUNTING_YEAR  \
# 0         950041          1                         2019
# 1         950041          1                         2019
# 2         950041          1                         2019
# 3         950041          1                         2019
# 4         950041          1                         2019
#
#    TRANSACTION_ACCOUNTING_MONTH TRANSACTION_EFFECTIVE_DATE  \
# 0                             9                  16-SEP-19
# 1                             9                  16-SEP-19
# 2                             9                  16-SEP-19
# 3                             9                  16-SEP-19
# 4                             9                  16-SEP-19
#
#   COVERAGE_INCEPTION_DATE EARN_EXPIRATION_DATE POLICY_EFFECTIVE_DATE  \
# 0               16-SEP-19            16-SEP-20             16-SEP-19
# 1               16-SEP-19            16-SEP-20             16-SEP-19
# 2               16-SEP-19            16-SEP-20             16-SEP-19
# 3               16-SEP-19            16-SEP-20             16-SEP-19
# 4               16-SEP-19            16-SEP-20             16-SEP-19
#
#   EXPIRATION_DATE  POLICY_NUMBER       ...         TRANS_TYPE_CODE  \
# 0       16-SEP-20        2509018       ...                       1
# 1       16-SEP-20        2509018       ...                       1
# 2       16-SEP-20        2509018       ...                       1
# 3       16-SEP-20        2509018       ...                       1
# 4       16-SEP-20        2509018       ...                       1
#
#    ZIP_CODE_FIRST5 DEDUCTIBLE_CODE RATE_DEPARTURE_FACTOR  \
# 0                0               1                     0
# 1                0              11                     0
# 2                0               1                     0
# 3                0               1                     0
# 4                0               1                     0
#
#   RATE_MOD_FACTOR_PACKAGE RATE_MOD_FACTOR_EXPENSE RATE_MOD_FACTOR_IRPM_SRP  \
# 0                       0                       0                        0
# 1                       0                       0                        0
# 2                       0                       0                        0
# 3                       0                       0                        0
# 4                       0                       0                        0
#
#   NO_OF_FAMILIES  CONSTRUCTION_TYPE  PROTECTION_CODE
# 0              1                  0                0
# 1              1                  3                0
# 2              1                  0                0
# 3              1                  0                0
# 4              1                  0                0
#
# [5 rows x 94 columns]

# %%
# Produce profiling report and save to file
profile = pandas_profiling.ProfileReport(data)
profile.to_file("./report_new.html")
# Out:
# C:\Users\dharcourt\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas_profiling\model\correlations.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   return np.sqrt(phi2corr / min((kcorr - 1.0), (rcorr - 1.0)))
# C:\Users\dharcourt\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas_profiling\model\correlations.py:124: UserWarning: There was an attempt to calculate the cramers correlation, but this failed.
# To hide this warning, disable the calculation
# (using `df.profile_report(correlations={"cramers": False}`)
# If this is problematic for your use case, please report this as an issue:
# https://github.com/pandas-profiling/pandas-profiling/issues
# (include the error message: 'The internally computed table of expected frequencies has a zero element at (0, 5).')
#   correlation_name=correlation_name, error=error
